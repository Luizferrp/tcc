# %%
import pandas as pd
from analyze import analyzer

# %%
df = pd.read_csv("dummydata.csv", header=None)

# %%
df.head()
# Out:
#          0          1                 2      3
# 0      Cor  Avaliação  Temperatura (°C)  Idade
# 1    Preto      Médio              22.0     76
# 2  Amarelo        Bom               9.6     73
# 3    Verde       Ruim              21.9     63
# 4     Azul        Bom              13.6     82

# %%
df.describe()
# Out:
#               0      1    2    3
# count       101    101  101  101
# unique        7      5   53   46
# top     Amarelo  Médio  9.6   89
# freq         21     29    4    9

# %%
df.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# dtype: object

# %%
cdf = analyzer(df)
# Out:
# A coluna  0  não é numérica, então não pode ser analisada.
# A coluna  1  não é numérica, então não pode ser analisada.
# A coluna  2  não é numérica, então não pode ser analisada.
# A coluna  3  não é numérica, então não pode ser analisada.

# %%
cdf.gen_plot()

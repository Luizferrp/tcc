# %%
from lazylib import make, AlexNet, device
import torch

# %%
all_metrics, model = make(
  model=AlexNet(x=128).to(device()),
  epocs= 1, 
  csv_path = "/home/luizp/projects/pibit/src/data/processed/csv/cicClean.csv",
  batch_size = 8192
)
# Out:
# Epoch 1: 100%|██████████| 782/782 [04:55<00:00,  2.65it/s, acc=0.973, loss=0.075]
# Epoch 1 Metrics:
# Accuracy: 0.9729
# F1 Score: 0.9733
# Precision: 0.9596
# Recall: 0.9873
# ROC AUC: 0.9962
#               precision    recall  f1-score   support
#
#       normal     0.9869    0.9584    0.9725     49949
#       ataque     0.9596    0.9873    0.9733     50051
#
#     accuracy                         0.9729    100000
#    macro avg     0.9733    0.9729    0.9729    100000
# weighted avg     0.9733    0.9729    0.9729    100000
# /home/luizp/projects/puc/tcc/venv/lib64/python3.13/site-packages/sklearn/metrics/_plot/roc_curve.py:189: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax_.legend(loc="lower right")
# Gráfico salvo em: ./resultados/epoch_1_metricas.png
# Epoch 1: 100%|██████████| 7032/7032 [16:45:26<00:00,  8.58s/it, acc=0.998, loss=0.0134]
# Epoch 1 Metrics:
# Accuracy: 0.9975
# F1 Score: 0.9975
# Precision: 0.9975
# Recall: 0.9976
# ROC AUC: 0.9996
#               precision    recall  f1-score   support
#
#       normal     0.9976    0.9975    0.9975    450051
#       ataque     0.9975    0.9976    0.9975    449949
#
#     accuracy                         0.9975    900000
#    macro avg     0.9975    0.9975    0.9975    900000
# weighted avg     0.9975    0.9975    0.9975    900000
# /home/luizp/projects/puc/tcc/venv/lib64/python3.13/site-packages/sklearn/metrics/_plot/roc_curve.py:189: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax_.legend(loc="lower right")
# Gráfico salvo em: ./resultados/epoch_1_metricas.png
# Finished experiment!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 make(
#       2   model=AlexNet(x=128).to('cpu'),
#       3   epocs= 1,
#       4   batch_size = 8192,
#       5   csv_path = "/home/luizp/projects/pibit/src/data/processed/csv/cicClean.csv"
#       6 )
#
# File ~/projects/puc/tcc/venv/lib64/python3.13/site-packages/lazylib/make.py:53, in make(model, epocs, batch_size, csv_path, xcol, lr, transform)
#      48     # register(, f'{out_path}-train--{epoch}')
#      49     # register(, f'{out_path}-valid--{epoch}')
#      50     #print(valid_m[epoch-1]["confusion_matrix"])
#      52 print("Finished experiment!")
# ---> 53 return MODEL
#
# NameError: name 'MODEL' is not defined

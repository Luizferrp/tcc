# %%
from lazylib import make, AlexNet, device, takeConfusionMatrix, takeRocCurve, now, register
import torch

# %%
n = now()
epocs = 1
model, metrics = make(
    EPOCHS=epocs, 
    BATCH_SIZE=128, 
    LEARNING_RATE=1e-3, 
    csv_path="/home/luizp/projects/pibit/src/data/processed/csv/cicClean.csv", 
    MODEL=AlexNet(x=128).to(device()), 
    SEED=1701,
    xcol=1
    ) 
register(metrics, f"/home/luizp/projects/pibit/src/0utput/text/{n}.txt")
torch.save(model.state_dict(), f"/home/luizp/projects/pibit/src/0utput/models/{n}_alexnet_{epocs}.nnModel")
# Out:
# [25-02-2024 16-22-17] Epoch 001 Acc: 0.9810 Loss: 0.05878601: 100%|██████████| 782/782 [00:16<00:00, 48.18it/s]
# [25-02-2024 16-23-37] Epoch 001 Val. Acc: 0.9933 Val. Loss: 0.02936955: 100%|██████████| 7032/7032 [01:19<00:00, 88.74it/s]
# [449362   5351    689 444598]
# [25-02-2024 16-23-58] Epoch 002 Acc: 0.9972 Loss: 0.01534547: 100%|██████████| 782/782 [00:18<00:00, 42.42it/s]
# [25-02-2024 16-26-33] Epoch 002 Val. Acc: 0.9981 Val. Loss: 0.00915545: 100%|██████████| 7032/7032 [02:34<00:00, 45.58it/s]
# [449418   1055    633 448894]
# Finished experiment!

# %%
cm = takeConfusionMatrix(metrics, epocs-1, f"/home/luizp/projects/pibit/src/0utput/img/confusionMatix/{n}.png")

# %%
takeRocCurve(metrics, epocs-1, f"/home/luizp/projects/pibit/src/0utput/img/rocCurve/{n}.png")
